# %%
import json
import pandas as pd
import numpy as np
import pickle

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)

# %%
pickle_in = open(r"C:\Users\surya\Desktop\Jupyter Python Programs\Amazon Review NLP\clean_all_data_df.pickle", 'rb')
clean_all_data_df = pickle.load(pickle_in)
clean_all_data_df
# Out:
#         overall verified   reviewTime      reviewerID        asin  \
# 0           5.0     True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1           5.0     True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2           3.0     True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3           2.0     True   02 4, 2014   A1M117A53LEI8  7508492919
# 4           4.0     True   02 3, 2014  A272DUT8M88ZS8  7508492919
# ...         ...      ...          ...             ...         ...
# 1128432     4.0     True  12 22, 2016  A1QWMCG1FNEP3A  B01HJC7N4C
# 1128433     5.0    False  07 15, 2016  A3FOBEJ9UVUTR3  B01HJC7N4C
# 1128434     5.0    False  07 14, 2016   AMUEAMKB4E33M  B01HJC7N4C
# 1128435     5.0    False  07 13, 2016  A2EV91MMOJ3IL4  B01HJC7N4C
# 1128436     5.0     True  05 11, 2017   ARKQD9Z1VPOV2  B01HJH9IN6
#
#                         style      reviewerName  \
# 0        {'Color:': ' Bling'}  Claudia Valdivia
# 1                         nan       sarah ponce
# ...

# %%
pickle_in = open(r"C:\Users\surya\Desktop\Jupyter Python Programs\Amazon Review NLP\clean_meta_df.pickle", 'rb')
clean_meta_df = pickle.load(pickle_in)
clean_meta_df
# Out:
#                                                  category tech1  \
# 0       ['Cell Phones & Accessories', 'Accessories', '...
# 1       ['Cell Phones & Accessories', 'Accessories', '...
# 2       ['Cell Phones & Accessories', 'Cases, Holsters...
# 3       ['Cell Phones & Accessories', 'Cases, Holsters...
# 4       ['Cell Phones & Accessories', 'Cases, Holsters...
# ...                                                   ...   ...
# 590066  ['Cell Phones & Accessories', 'Accessories', '...
# 590067  ['Cell Phones & Accessories', 'Cases, Holsters...
# 590068  ['Cell Phones & Accessories', 'Cases, Holsters...
# 590069  ['Cell Phones & Accessories', 'Cases, Holsters...
# 590070  ['Cell Phones & Accessories', 'Cases, Holsters...
#
#                                               description fit  \
# 0                                                      []
# 1                                                      []
# 2       ['New items to give you a new good mood, welco...
# ...

# %%
from functools import reduce

common_asin = list(reduce(set.intersection, map(set, [clean_all_data_df.asin, clean_meta_df.asin])))
common_asin
# Out:
# ['B00S6DQ37W',
#  'B01B8T7MA2',
#  'B00CM5H572',
#  'B00PB91RLG',
#  'B01G2YN0Q8',
#  'B00APEIXOG',
#  'B00GIVSZVG',
#  'B01BLLJJW6',
#  'B018EJMPAG',
#  'B00F58RISO',
#  'B019JY97QA',
#  'B01GGLCVWQ',
#  'B000QGQRX2',
#  'B004Q3PYIU',
#  'B009CJ6YSM',
#  'B00RIZN3PO',
#  'B00CTK3AY2',
#  'B00QHRDG74',
#  'B005LY553M',
#  'B00ACCB34S',
#  'B00NHYN2VU',
#  'B00UYJPH96',
#  'B01A5GO248',
#  'B011B8CRGE',
#  'B01G6QVR62',
#  'B00KPAXXC2',
#  'B00Y3Y0RAM',
#  'B00N2911W2',
#  'B01DUHC82W',
#  'B01D221FWE',
#  'B00PSR7PJO',
#  'B000VXHCPC',
#  'B00AAH8OWO',
#  'B00KBY9WNG',
#  'B004UAG6WC',
#  'B00B1WRFV8',
#  'B00KGVCCRM',
#  'B00P9H1MAQ',
#  'B00WBR49UM',
#  'B00ABMPJHQ',
#  'B012BM8C18',
#  'B0172XGFU6',
#  'B005YUDK6W',
#  'B01DQGRVJM',
#  'B00JZKKQHS',
#  'B00NBKYHIM',
#  'B00CL5C884',
#  'B00AIG7Z1I',
#  'B00MBTMDNU',
#  'B00NCYMF40',
#  'B00PL4IOUS',
#  'B003UWSIFO',
#  'B00QPAT7A8',
#  'B00BYJXLV6',
#  'B00264FS3W',
#  'B019LDO33Q',
#  'B003LVDWOQ',
#  'B0061XLXX8',
# ...

# %%
len(common_asin)
# Out:
# 48172

# %%
combined_df = pd.merge(clean_all_data_df, clean_meta_df, on='asin')

# %%
combined_df.sort_values('asin')
# Out:
#         overall verified   reviewTime      reviewerID        asin  \
# 0           5.0     True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 35          4.0     True  01 29, 2013  A31ZGF7EGCAFKI  7508492919
# 36          4.0     True  01 27, 2013   A6XZQP4XMD75X  7508492919
# 37          4.0     True  01 18, 2013   ANETWIJI7GX0W  7508492919
# 38          4.0     True  01 16, 2013  A1BTAZYRTE2BOW  7508492919
# ...         ...      ...          ...             ...         ...
# 1119960     1.0     True   09 1, 2016   A4DTRG6NC8CED  B01HJH9IN6
# 1119961     3.0     True  08 18, 2016   A5CNVTMYJXH53  B01HJH9IN6
# 1119962     5.0     True  07 19, 2016  A1E2L0XMC1BYQO  B01HJH9IN6
# 1119963     5.0     True  05 11, 2017   ARKQD9Z1VPOV2  B01HJH9IN6
# 1119958     5.0     True  11 17, 2016  A2FJBX7C9GKVZL  B01HJH9IN6
#
#                         style      reviewerName  \
# 0        {'Color:': ' Bling'}  Claudia Valdivia
# 35                        nan           Lizette
# ...

# %%
data = combined_df[combined_df['main_cat'] == 'Cell Phones & Accessories']
data
# Out:
#         overall verified   reviewTime      reviewerID        asin  \
# 0           5.0     True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1           5.0     True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2           3.0     True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3           2.0     True   02 4, 2014   A1M117A53LEI8  7508492919
# 4           4.0     True   02 3, 2014  A272DUT8M88ZS8  7508492919
# ...         ...      ...          ...             ...         ...
# 1124857     5.0     True   10 3, 2016  A3Q7GA2Q62E18Q  B01HE0RNYO
# 1124858     5.0    False  07 18, 2016   AEKOIX49JGCUG  B01HE0RNYO
# 1124859     4.0    False  07 16, 2016  A2KOKSKEDIBRGQ  B01HE0RNYO
# 1124860     3.0    False  07 11, 2016  A1BO3NH4KKASUT  B01HE0RNYO
# 1124861     5.0    False   07 8, 2016  A2EYEG7K8JEPJE  B01HE0RNYO
#
#                         style      reviewerName  \
# 0        {'Color:': ' Bling'}  Claudia Valdivia
# 1                         nan       sarah ponce
# ...

# %%
clean_meta_df.columns
# Out:
# Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'details', 'main_cat',
#        'similar_item', 'date', 'price', 'asin', 'imageURL', 'imageURLHighRes'],
#       dtype='object')

# %%
drop_cols = ['category', 'tech1', 'fit', 'title', 'also_buy', 'tech2', 'brand', 'also_view', 'details', 'similar_item', 
             'date', 'price']

# %%
data.drop(drop_cols, axis=1, inplace = True)
# Out:
# C:\Users\surya\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#         overall verified   reviewTime      reviewerID        asin  \
# 0           5.0     True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1           5.0     True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2           3.0     True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3           2.0     True   02 4, 2014   A1M117A53LEI8  7508492919
# 4           4.0     True   02 3, 2014  A272DUT8M88ZS8  7508492919
# ...         ...      ...          ...             ...         ...
# 1041972     5.0     True   10 3, 2016  A3Q7GA2Q62E18Q  B01HE0RNYO
# 1041973     5.0    False  07 18, 2016   AEKOIX49JGCUG  B01HE0RNYO
# 1041974     4.0    False  07 16, 2016  A2KOKSKEDIBRGQ  B01HE0RNYO
# 1041975     3.0    False  07 11, 2016  A1BO3NH4KKASUT  B01HE0RNYO
# 1041976     5.0    False   07 8, 2016  A2EYEG7K8JEPJE  B01HE0RNYO
#
#                         style      reviewerName  \
# 0        {'Color:': ' Bling'}  Claudia Valdivia
# 1                         nan       sarah ponce
# ...

# %%
data.to_csv(r"C:\Users\surya\Desktop\Jupyter Python Programs\Amazon Review NLP\Clean_CPA_data_csv.csv", index=False)

# %%
writer = pd.ExcelWriter(r"C:\Users\surya\Desktop\Jupyter Python Programs\Amazon Review NLP\Clean_CPA_data_excel.xlsx", engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer, index=False)
writer.close()
